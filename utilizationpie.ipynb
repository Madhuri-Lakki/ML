# %%
from reportlab.platypus import SimpleDocTemplate
from reportlab.graphics.charts.legends import Legend as legend
import reportlab.lib.colors as colors
from matplotlib import pyplot as plt
plt.rcParams['legend.handlelength'] = 1
plt.rcParams['legend.handleheight'] = 1.125
plt.rcParams['legend.numpoints'] = 1
#from reportlab.lib.colors import yellow, green, orange, HexColor
def main():
    data = [44,56]
    ##my_title = String(170, 40, 'My Pie Chart', fontSize=14)
    ##label1 = ['Running','Idling','Stopped',]
    cl = ['blue', 'darkorange']
    plt.pie(data, autopct = '%2.1f%%', colors = cl, startangle = 90, shadow = True,explode=(0.1,0))
    ax = plt.subplot(111)
    b1, =ax.plot([], marker="s", markersize=10, linestyle="", label='Utilization',color='blue')
    b2, =ax.plot([], marker="s", markersize=10, linestyle="", label='Un-utilization',color='darkorange')
    ax.legend(loc='upper right', bbox_to_anchor=(1.25, 1.00), shadow=True,ncol=1,handles=[b1, b2])
    ##plt.legend.defaultColors = [green, yellow, orangered]
    ##plt.legend()
    ##doc = SimpleDocTemplate('flowable_with_chart.pdf')
    
    ##elements = []
    circle = plt.Circle(xy=(0, 0), radius=0.75, facecolor='white')
    fig = plt.gca().add_artist(circle)
    fig = plt.savefig('/Users/lakkireddy.madhuri/reportlabs/utilpiechrt.jpg',transparent=False)
    plt.show()
    ##elements.append(fig)
    ##doc.build(elements)
    
if __name__ == '__main__':
    main()
